# %%
import pandas as pd
import re
from urllib.parse import urlparse
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from nltk.tokenize import TreebankWordTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns

plt.style.use('./deeplearning.mplstyle')

RANDOM_STATE = 42

# %%
df = pd.read_csv("training_spam_text.csv")

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['Type'])

# %%
# Exclude the target column
features = [x for x in df.columns if x != 'Type']  # Exclude 'type' column
print(len(features))
# Out:
# 5

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df[features], y, test_size=0.2, random_state=42)

print(f'train samples: {len(X_train)}')
print(f'validation samples: {len(X_test)}')
print(f'target proportion: {sum(y_train)/len(y_train):.4f}')
# Out:
# train samples: 800
# validation samples: 200
# target proportion: 0.4950

# %%
# Building decision tree 
# min_samples_split: The minimum number of samples required to split an internal ndoe
# max_depth: The maximum depth of the tree
# An additionaly hyperparameter for Random Forest is called n_estimators, which is the 
# number of Decision Tress that make up the Random Forest

min_samples_split_list = [2, 5, 10, 15, 20, 30, 40, 50, 60, 80, 100, 150, 200, 250, 300, 700]
max_depth_list = [1, 2, 3, 4, 5, 6, 7, 8, 10, 12, 16, 20, 32, 40, 64, None]
n_estimators_list = [10, 20, 50, 75, 100, 200, 500, 1000]

# %%
# Min Sample Split

accuracy_list_train = []
accuracy_list_val = []

for min_samples_split in min_samples_split_list:

    model = DecisionTreeClassifier(min_samples_split=min_samples_split,
                                   random_state=42).fit(X_train, y_train)
    predictions_train = model.predict(X_train)
    predictions_test = model.predict(X_test)
    accuracy_train = accuracy_score(predictions_train, y_train)
    accuracy_val = accuracy_score(predictions_test, y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

    print(f"min_samples_split={min_samples_split}, Train Accuracy={accuracy_train:.4f}, Validation Accuracy={accuracy_val:.4f}")

# plt.title('Train x Validation metrics')
# plt.xlabel('min_samples_split')
# plt.ylabel('accuracy')
# plt.xticks(ticks= range(len(min_samples_split_list)), labels=min_samples_split_list)
# plt.plot(accuracy_list_train)
# plt.plot(accuracy_list_val)
# plt.legend(['Train', 'Validation'])
# Out:
# min_samples_split=2, Train Accuracy=1.0000, Validation Accuracy=0.8000
# min_samples_split=5, Train Accuracy=0.9725, Validation Accuracy=0.8050
# min_samples_split=10, Train Accuracy=0.9350, Validation Accuracy=0.8150
# min_samples_split=15, Train Accuracy=0.9187, Validation Accuracy=0.8200
# min_samples_split=20, Train Accuracy=0.9113, Validation Accuracy=0.8300
# min_samples_split=30, Train Accuracy=0.9025, Validation Accuracy=0.8450
# min_samples_split=40, Train Accuracy=0.8900, Validation Accuracy=0.8300
# min_samples_split=50, Train Accuracy=0.8712, Validation Accuracy=0.8150
# min_samples_split=60, Train Accuracy=0.8662, Validation Accuracy=0.8200
# min_samples_split=80, Train Accuracy=0.8662, Validation Accuracy=0.8200
# min_samples_split=100, Train Accuracy=0.8662, Validation Accuracy=0.8200
# min_samples_split=150, Train Accuracy=0.8638, Validation Accuracy=0.8200
# min_samples_split=200, Train Accuracy=0.8638, Validation Accuracy=0.8200
# min_samples_split=250, Train Accuracy=0.8638, Validation Accuracy=0.8200
# min_samples_split=300, Train Accuracy=0.8638, Validation Accuracy=0.8200
# min_samples_split=700, Train Accuracy=0.8488, Validation Accuracy=0.8050

# %%
# Max depth 

accuracy_list_train = []
accuracy_list_val = []

for max_depth in max_depth_list:

    model = DecisionTreeClassifier(max_depth=max_depth,
                                   random_state=RANDOM_STATE).fit(X_train, y_train)
    predictions_train = model.predict(X_train)
    predictions_test = model.predict(X_test)
    accuracy_train = accuracy_score(predictions_train, y_train)
    accuracy_val = accuracy_score(predictions_test, y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

    print(f"max_depth={max_depth}, Train Accuracy={accuracy_train:.4f}, Validation Accuracy={accuracy_val:.4f}")

# plt.title('Train x Validation metrics')
# plt.xlabel('max_depth')
# plt.ylabel('accuracy')
# plt.xticks(ticks = range(len(max_depth_list )),labels=max_depth_list)
# plt.plot(accuracy_list_train)
# plt.plot(accuracy_list_val)
# plt.legend(['Train','Validation'])
# Out:
# max_depth=1, Train Accuracy=0.8488, Validation Accuracy=0.8050
# max_depth=2, Train Accuracy=0.8625, Validation Accuracy=0.8150
# max_depth=3, Train Accuracy=0.8700, Validation Accuracy=0.8250
# max_depth=4, Train Accuracy=0.8838, Validation Accuracy=0.8350
# max_depth=5, Train Accuracy=0.8975, Validation Accuracy=0.8100
# max_depth=6, Train Accuracy=0.9062, Validation Accuracy=0.8200
# max_depth=7, Train Accuracy=0.9313, Validation Accuracy=0.8150
# max_depth=8, Train Accuracy=0.9450, Validation Accuracy=0.8200
# max_depth=10, Train Accuracy=0.9637, Validation Accuracy=0.8250
# max_depth=12, Train Accuracy=0.9750, Validation Accuracy=0.8150
# max_depth=16, Train Accuracy=0.9975, Validation Accuracy=0.8050
# max_depth=20, Train Accuracy=1.0000, Validation Accuracy=0.8000
# max_depth=32, Train Accuracy=1.0000, Validation Accuracy=0.8000
# max_depth=40, Train Accuracy=1.0000, Validation Accuracy=0.8000
# max_depth=64, Train Accuracy=1.0000, Validation Accuracy=0.8000
# max_depth=None, Train Accuracy=1.0000, Validation Accuracy=0.8000

# %%
# N Estimators

accuracy_list_train = []
accuracy_list_val = []

for n_estimators in n_estimators_list:

    model = RandomForestClassifier(n_estimators=n_estimators,
                                   random_state=RANDOM_STATE).fit(X_train, y_train)
    predictions_train = model.predict(X_train)
    predictions_test = model.predict(X_test)
    accuracy_train = accuracy_score(predictions_train, y_train)
    accuracy_val = accuracy_score(predictions_test, y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

    print(f"n_estimators={n_estimators}, Train Accuracy={accuracy_train:.4f}, Validation Accuracy={accuracy_val:.4f}")

# plt.title('Train x Validation metrics')
# plt.xlabel('n_estimators')
# plt.ylabel('accuracy')
# plt.xticks(ticks = range(len(n_estimators_list )),labels=n_estimators_list)
# plt.plot(accuracy_list_train)
# plt.plot(accuracy_list_val)
# plt.legend(['Train','Validation'])
# Out:
# n_estimators=10, Train Accuracy=0.9825, Validation Accuracy=0.8450
# n_estimators=20, Train Accuracy=0.9975, Validation Accuracy=0.8300
# n_estimators=50, Train Accuracy=1.0000, Validation Accuracy=0.8450
# n_estimators=75, Train Accuracy=1.0000, Validation Accuracy=0.8500
# n_estimators=100, Train Accuracy=1.0000, Validation Accuracy=0.8450
# n_estimators=200, Train Accuracy=1.0000, Validation Accuracy=0.8450
# n_estimators=500, Train Accuracy=1.0000, Validation Accuracy=0.8450
# n_estimators=1000, Train Accuracy=1.0000, Validation Accuracy=0.8450

# %%
random_forest_model = RandomForestClassifier(min_samples_split = 100,
                                             max_depth = 3,
                                             n_estimators = 1000).fit(X_train,y_train)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(X_test),y_test):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.8600
# Metrics test:
# 	Accuracy score: 0.8150

# %%
n = int(len(X_train)*0.8)

# %%
X_train_fit, X_train_eval, y_train_fit, y_train_eval = X_train[:n], X_train[n:], y_train[:n], y_train[n:]

# %%
# eval_set = [(X_train_eval,y_train_eval)]:Here we must pass a list to the eval_set, because you can have several different tuples ov eval sets.
# early_stopping_rounds: This parameter helps to stop the model training if its evaluation metric is no longer improving on the validation set. It's set to 10.

# This code builds and trains a smart model to make predictions, and it tries to avoid overfitting by stopping early if the model stops improving.
# xgb_model = XGBClassifier(n_estimators = 500, learning_rate = 0.1,verbosity = 1, random_state = RANDOM_STATE, early_stopping_rounds = 15)
xgb_model = XGBClassifier(n_estimators = 200, learning_rate = 0.01,verbosity = 1, random_state = RANDOM_STATE, early_stopping_rounds=10)
xgb_model.fit(X_train_fit,y_train_fit, eval_set = [(X_train_eval,y_train_eval)])
# Out:
# [0]	validation_0-logloss:0.68845
# [1]	validation_0-logloss:0.68267
# [2]	validation_0-logloss:0.67688
# [3]	validation_0-logloss:0.67131
# [4]	validation_0-logloss:0.66588
# [5]	validation_0-logloss:0.66041
# [6]	validation_0-logloss:0.65523
# [7]	validation_0-logloss:0.65026
# [8]	validation_0-logloss:0.64521
# [9]	validation_0-logloss:0.64031
# [10]	validation_0-logloss:0.63563
# [11]	validation_0-logloss:0.63072
# [12]	validation_0-logloss:0.62620
# [13]	validation_0-logloss:0.62177
# [14]	validation_0-logloss:0.61725
# [15]	validation_0-logloss:0.61285
# [16]	validation_0-logloss:0.60866
# [17]	validation_0-logloss:0.60424
# [18]	validation_0-logloss:0.60022
# [19]	validation_0-logloss:0.59625
# [20]	validation_0-logloss:0.59221
# [21]	validation_0-logloss:0.58819
# [22]	validation_0-logloss:0.58413
# [23]	validation_0-logloss:0.58035
# [24]	validation_0-logloss:0.57671
# [25]	validation_0-logloss:0.57289
# [26]	validation_0-logloss:0.56938
# [27]	validation_0-logloss:0.56598
# [28]	validation_0-logloss:0.56240
# [29]	validation_0-logloss:0.55910
# [30]	validation_0-logloss:0.55565
# [31]	validation_0-logloss:0.55236
# [32]	validation_0-logloss:0.54924
# [33]	validation_0-logloss:0.54591
# [34]	validation_0-logloss:0.54289
# [35]	validation_0-logloss:0.53970
# [36]	validation_0-logloss:0.53671
# [37]	validation_0-logloss:0.53367
# [38]	validation_0-logloss:0.53089
# [39]	validation_0-logloss:0.52783
# [40]	validation_0-logloss:0.52509
# [41]	validation_0-logloss:0.52227
# [42]	validation_0-logloss:0.51956
# [43]	validation_0-logloss:0.51703
# [44]	validation_0-logloss:0.51440
# [45]	validation_0-logloss:0.51175
# [46]	validation_0-logloss:0.50914
# [47]	validation_0-logloss:0.50669
# [48]	validation_0-logloss:0.50414
# [49]	validation_0-logloss:0.50183
# [50]	validation_0-logloss:0.49951
# [51]	validation_0-logloss:0.49714
# [52]	validation_0-logloss:0.49486
# [53]	validation_0-logloss:0.49273
# [54]	validation_0-logloss:0.49037
# [55]	validation_0-logloss:0.48804
# [56]	validation_0-logloss:0.48589
# [57]	validation_0-logloss:0.48358
# [58]	validation_0-logloss:0.48150
# [59]	validation_0-logloss:0.47927
# [60]	validation_0-logloss:0.47725
# [61]	validation_0-logloss:0.47511
# [62]	validation_0-logloss:0.47321
# [63]	validation_0-logloss:0.47113
# [64]	validation_0-logloss:0.46923
# [65]	validation_0-logloss:0.46721
# [66]	validation_0-logloss:0.46536
# [67]	validation_0-logloss:0.46341
# [68]	validation_0-logloss:0.46169
# [69]	validation_0-logloss:0.45979
# [70]	validation_0-logloss:0.45795
# [71]	validation_0-logloss:0.45623
# [72]	validation_0-logloss:0.45462
# [73]	validation_0-logloss:0.45286
# [74]	validation_0-logloss:0.45106
# [75]	validation_0-logloss:0.44935
# [76]	validation_0-logloss:0.44781
# [77]	validation_0-logloss:0.44633
# [78]	validation_0-logloss:0.44463
# [79]	validation_0-logloss:0.44317
# [80]	validation_0-logloss:0.44174
# [81]	validation_0-logloss:0.44017
# [82]	validation_0-logloss:0.43855
# [83]	validation_0-logloss:0.43720
# [84]	validation_0-logloss:0.43563
# [85]	validation_0-logloss:0.43421
# [86]	validation_0-logloss:0.43293
# [87]	validation_0-logloss:0.43142
# [88]	validation_0-logloss:0.43004
# [89]	validation_0-logloss:0.42871
# [90]	validation_0-logloss:0.42748
# [91]	validation_0-logloss:0.42611
# [92]	validation_0-logloss:0.42471
# [93]	validation_0-logloss:0.42350
# [94]	validation_0-logloss:0.42215
# [95]	validation_0-logloss:0.42090
# [96]	validation_0-logloss:0.41962
# [97]	validation_0-logloss:0.41821
# [98]	validation_0-logloss:0.41701
# [99]	validation_0-logloss:0.41591
# [100]	validation_0-logloss:0.41484
# [101]	validation_0-logloss:0.41363
# [102]	validation_0-logloss:0.41257
# [103]	validation_0-logloss:0.41147
# [104]	validation_0-logloss:0.41040
# [105]	validation_0-logloss:0.40929
# [106]	validation_0-logloss:0.40822
# [107]	validation_0-logloss:0.40725
# [108]	validation_0-logloss:0.40627
# [109]	validation_0-logloss:0.40510
# [110]	validation_0-logloss:0.40432
# [111]	validation_0-logloss:0.40327
# [112]	validation_0-logloss:0.40229
# [113]	validation_0-logloss:0.40124
# [114]	validation_0-logloss:0.40030
# [115]	validation_0-logloss:0.39923
# [116]	validation_0-logloss:0.39815
# [117]	validation_0-logloss:0.39723
# [118]	validation_0-logloss:0.39632
# [119]	validation_0-logloss:0.39557
# [120]	validation_0-logloss:0.39462
# [121]	validation_0-logloss:0.39370
# [122]	validation_0-logloss:0.39292
# [123]	validation_0-logloss:0.39219
# [124]	validation_0-logloss:0.39117
# [125]	validation_0-logloss:0.39050
# [126]	validation_0-logloss:0.38965
# [127]	validation_0-logloss:0.38889
# [128]	validation_0-logloss:0.38794
# [129]	validation_0-logloss:0.38700
# [130]	validation_0-logloss:0.38628
# [131]	validation_0-logloss:0.38550
# [132]	validation_0-logloss:0.38482
# [133]	validation_0-logloss:0.38416
# [134]	validation_0-logloss:0.38321
# [135]	validation_0-logloss:0.38261
# [136]	validation_0-logloss:0.38181
# [137]	validation_0-logloss:0.38124
# [138]	validation_0-logloss:0.38058
# [139]	validation_0-logloss:0.37973
# [140]	validation_0-logloss:0.37911
# [141]	validation_0-logloss:0.37841
# [142]	validation_0-logloss:0.37774
# [143]	validation_0-logloss:0.37706
# [144]	validation_0-logloss:0.37641
# [145]	validation_0-logloss:0.37588
# [146]	validation_0-logloss:0.37540
# [147]	validation_0-logloss:0.37479
# [148]	validation_0-logloss:0.37410
# [149]	validation_0-logloss:0.37356
# [150]	validation_0-logloss:0.37304
# [151]	validation_0-logloss:0.37252
# [152]	validation_0-logloss:0.37196
# [153]	validation_0-logloss:0.37142
# [154]	validation_0-logloss:0.37090
# [155]	validation_0-logloss:0.37038
# [156]	validation_0-logloss:0.36996
# [157]	validation_0-logloss:0.36947
# [158]	validation_0-logloss:0.36898
# [159]	validation_0-logloss:0.36849
# [160]	validation_0-logloss:0.36802
# [161]	validation_0-logloss:0.36753
# [162]	validation_0-logloss:0.36704
# [163]	validation_0-logloss:0.36658
# [164]	validation_0-logloss:0.36612
# [165]	validation_0-logloss:0.36567
# [166]	validation_0-logloss:0.36521
# [167]	validation_0-logloss:0.36464
# [168]	validation_0-logloss:0.36427
# [169]	validation_0-logloss:0.36367
# [170]	validation_0-logloss:0.36313
# [171]	validation_0-logloss:0.36281
# [172]	validation_0-logloss:0.36225
# [173]	validation_0-logloss:0.36191
# [174]	validation_0-logloss:0.36136
# [175]	validation_0-logloss:0.36103
# [176]	validation_0-logloss:0.36055
# [177]	validation_0-logloss:0.36025
# [178]	validation_0-logloss:0.35973
# [179]	validation_0-logloss:0.35927
# [180]	validation_0-logloss:0.35899
# [181]	validation_0-logloss:0.35849
# [182]	validation_0-logloss:0.35822
# [183]	validation_0-logloss:0.35779
# [184]	validation_0-logloss:0.35731
# [185]	validation_0-logloss:0.35709
# [186]	validation_0-logloss:0.35668
# [187]	validation_0-logloss:0.35622
# [188]	validation_0-logloss:0.35602
# [189]	validation_0-logloss:0.35558
# [190]	validation_0-logloss:0.35530
# [191]	validation_0-logloss:0.35495
# [192]	validation_0-logloss:0.35449
# [193]	validation_0-logloss:0.35411
# [194]	validation_0-logloss:0.35397
# [195]	validation_0-logloss:0.35351
# [196]	validation_0-logloss:0.35327
# [197]	validation_0-logloss:0.35292
# [198]	validation_0-logloss:0.35254
# [199]	validation_0-logloss:0.35216
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# Generate predictions on test data
y_pred_url = xgb_model.predict(X_test)

# Save predictions for meta-model training
url_predictions = pd.DataFrame({"text_pred": y_pred_url, "type": y_test})
url_predictions.to_csv("text_model_predictions.csv", index=False)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_test),y_test):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.9137
# Metrics test:
# 	Accuracy score: 0.8450

# %%
cm = confusion_matrix(y_test, xgb_model.predict(X_test))
print(cm)
# Get the confusion matrix
cm = confusion_matrix(y_test, xgb_model.predict(X_test))

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[85 11]
#  [20 84]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, random_forest_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82        96
#            1       0.85      0.78      0.81       104
#
#     accuracy                           0.81       200
#    macro avg       0.82      0.82      0.81       200
# weighted avg       0.82      0.81      0.81       200

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(model, X_test, y_test, scoring="accuracy")

importance_df = pd.DataFrame({
    "Feature": X_test.columns,
    "Importance": perm_importance.importances_mean
}).sort_values(by="Importance", ascending=False)

print(importance_df)

sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(X_test.columns[sorted_idx], perm_importance.importances_mean[sorted_idx])
plt.xlabel("Permutation Importance")
plt.show()
# Out:
#                 Feature  Importance
# 0           text_length       0.142
# 2       avg_word_length       0.027
# 3  num_suspicious_words       0.017
# 4      num_exclamations       0.016
# 1             num_words       0.006

# %%
def extract_features(text):
    
    feature = {}
    
    text = text.lower()
    tokenizer = TreebankWordTokenizer()
    tokens = tokenizer.tokenize(text) 
    tokens = [word for word in tokens if word.isalnum()]
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    feature['text_length'] = len(text)
    feature['num_words'] = len(tokens)
    feature['avg_word_length'] = sum(len(word) for word in tokens) / len(tokens) if len(tokens) > 0 else 0

    suspicious_words = ['free', 'win', 'urgent', 'click', 'buy', 'money', 'offer']
    feature['num_suspicious_words'] = sum(1 for word in tokens if word in suspicious_words)

    feature['num_exclamations'] = text.count('!')

    return feature

# %%
text = "u r subscribed 2 TEXTCOMP 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020"
# text = "Nur Deeni Binti Deti Affendi"

new_features = extract_features(text)

new_features_df = pd.DataFrame([new_features])

prediction = random_forest_model.predict(new_features_df)

predicted_class = label_encoder.inverse_transform(prediction)

print(f"Prediction for Text '{text}': {predicted_class[0]}")
# Out:
# Prediction for Text 'u r subscribed 2 TEXTCOMP 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020': harmful

# %%
# import joblib
# joblib.dump(xgb_model, "text_model.joblib")

# xgb_model.save_model("text_model.json")
